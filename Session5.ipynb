# %%
# Tasks
# 1. Create a list called playlist_ids with 5 song IDs (as integers) that you might see in a Spotify playlist, and print the list.
# 2. Add two more song IDs to your playlist_ids list using both append() and extend(), then print the updated list.<br><br><em><strong>Hint:</strong> Use append() for a single ID and extend() for adding multiple IDs at once.</em>
# 3. Simulate removing the last played song from your playlist_ids list using pop(), and display the removed ID along with the remaining playlist.
# 4. Create a tuple called insta_filters with 4 Instagram filter names (as strings). Try to change the first filter name and observe what error you get.<br><br><em><strong>Hint:</strong> Tuples are immutable. Note down the error message.</em>
# 5. Write a short Python script that takes a scenario (like a list of recent Zomato orders vs a tuple of fixed IPL team names) and prints which one should use a list and which should use a tuple, explaining your choice in a comment.

# %%
#Task 1
playlist_ids=[1001,1002,1003,1004,1005]
playlist_ids
# Out:
# [1001, 1002, 1003, 1004, 1005]

# %%
#Task 2
playlist_ids.append(1006)

# %%
playlist_ids
# Out:
# [1001, 1002, 1003, 1004, 1005, 1006]

# %%
playlist_ids.extend([1025])

# %%
playlist_ids
# Out:
# [1001, 1002, 1003, 1004, 1005, 1006, 1025]

# %%
#Task 3
playlist_ids.pop()
# Out:
# 1025

# %%
playlist_ids
# Out:
# [1001, 1002, 1003, 1004, 1005, 1006]

# %%
#Task 4
insta_filters= ("a","b","c","d")
print(type(insta_filters))
# Out:
# <class 'tuple'>

# %%
# insta_filters.replace("a","e")   
# 'tuple' object has no attribute 'replace'
# tuples are immutable.

# %%
#Task 5
order1=["noodles","french fries","mango juice"]
order2=["burger","coca cola"]
IPL_Team=("CSK","MI","GT","KKR","SRH","RCB")

# %%
#Order 1 and Order 2 are the list. which help to made a changes in the list and list is mutuable so we can make the changes in the list . Changes like Add,Append,pop,etc. functions are used.
print(order1)
print("Type of Order 1 is :",type(order1))
print(order2)
print("Type of Order 2 is :",type(order2)) 

#IPL_TEAM is a tuple and we cannot make the changes in this after creation of the tuple.
print(IPL_Team)
print("Type of IPL_Team is :",type(IPL_Team))
# Out:
# ['noodles', 'french fries', 'mango juice']
# Type of Order 1 is : <class 'list'>
# ['burger', 'coca cola']
# Type of Order 2 is : <class 'list'>
# ('CSK', 'MI', 'GT', 'KKR', 'SRH', 'RCB')
# Type of IPL_Team is : <class 'tuple'>
