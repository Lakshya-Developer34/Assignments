# %%
# Tasks
# 1. Define a function called calculate_final_price(price, discount_rate) that returns the final price after applying the discount rate to the given price.
# 2. Create a function called get_delivery_charge(amount, city='Ahmedabad') that returns 0 if city is 'Ahmedabad', otherwise returns 50 as a delivery charge.<br><br><em><strong>Hint:</strong> Use a default argument for the city parameter.</em>
# 3. Write a function called format_price(price, currency='INR') that returns a string like '₹500' if currency is 'INR', or '$500' if currency is 'USD'.
# 4. Build a function called apply_coupon(price, coupon_code=None) that returns the price after a 10% discount if coupon_code is 'ZOMATO10', otherwise returns the original price.<br><br><em><strong>Constraint:</strong> Use a default argument for coupon_code.</em

# %%
#Task 1
def  calculate_final_price(price,discount_rate):
    print("Your Given Price is :",price)
    if price>10000:
        disc_price= price*discount_rate/100
        print("Your Discount is ",disc_price)
        price=price-disc_price
        print("After discount you new price is :",price)
    else: 
        print("No Discount Your price is less than 10000")

# %%
calculate_final_price(20000,10)
# Out:
# Your Given Price is : 20000
# Your Discount is  2000.0
# After discount you new price is : 18000.0

# %%
#Task 2
def get_delivery_charge(amount, city="Ahmedabad"):
   if city=="Ahmedabad"or city=="ahmedabad":
        print("Your product amount is",amount,"And You have Zero Delivery Charges")
   else:
       print("Your product amount is",amount,"And Your Delivery Charges is 50")

# %%
get_delivery_charge(5000,"ahmedabad")
# Out:
# Your product amount is 5000 And You have Zero Delivery Charges

# %%
# Task 3
def format_price(price,currency="INR"):
    if currency=="INR":
        print("Your Amount is :₹",price)
    elif currency=="USD":
        print("Your Amount is :$",price)
    else:
        print("Invalid")

# %%
format_price(1000,"INR")
# Out:
# Your Amount is :₹ 1000

# %%
format_price(20000,"USD")
# Out:
# Your Amount is :$ 20000

# %%
#Task 4
def apply_coupon(price, coupon_code=None):
    if coupon_code=="ZOMATO10":
        discounted_price= price*10/100
        price=price-discounted_price
        print("Your 10% Discount is ",discounted_price ,"And After discount Your new price is",price)
    else:
        print("Sorry You have no discount and your product price is",price)

# %%
apply_coupon(1000,"ZOMATO10")
# Out:
# Your 10% Discount that is  100.0 And After discount Your new price is 900.0
